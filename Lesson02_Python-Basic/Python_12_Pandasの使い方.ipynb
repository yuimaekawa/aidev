# %% [markdown]
# ## CSVファイルを読み込む

# %%
import pandas as pd

# %%
df = pd.read_csv("./sample_data/california_housing_train.csv")

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ## データを表示する

# %% [markdown]
# ### とりあえず表示する

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
print(df)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %% [markdown]
# ### インデックスで行を指定する

# %%
df.iloc[1, :]    # 1行目の全列のデータを取得
# Out:
# longitude              -114.47
# latitude                 34.40
# housing_median_age       19.00
# total_rooms            7650.00
# total_bedrooms         1901.00
# population             1129.00
# households              463.00
# median_income             1.82
# median_house_value    80100.00
# Name: 1, dtype: float64

# %%
type(df.iloc[1, :])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0:3, :]    # 0行目から2行目までの全列のデータを取得
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0

# %%
df.iloc[:11:2, :]    # 先頭から10行目まで（増分2で）の全列のデータを取得
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.31     34.19                15.0       5612.0          1283.0
# 2     -114.56     33.69                17.0        720.0           174.0
# 4     -114.57     33.57                20.0       1454.0           326.0
# 6     -114.58     33.61                25.0       2907.0           680.0
# 8     -114.59     33.61                34.0       4789.0          1175.0
# 10    -114.60     33.62                16.0       3741.0           801.0
#
#     population  households  median_income  median_house_value
# 0       1015.0       472.0         1.4936             66900.0
# 2        333.0       117.0         1.6509             85700.0
# 4        624.0       262.0         1.9250             65500.0
# 6       1841.0       633.0         2.6768             82400.0
# 8       3134.0      1056.0         2.1782             58400.0
# 10      2434.0       824.0         2.6797             86500.0

# %% [markdown]
# #### 補足：ilocの列でのスライス

# %%
df.iloc[:10, :2]    # 0行目から9行目まで・0列目から1列目までのデータを取得
# Out:
#    longitude  latitude
# 0    -114.31     34.19
# 1    -114.47     34.40
# 2    -114.56     33.69
# 3    -114.57     33.64
# 4    -114.57     33.57
# 5    -114.58     33.63
# 6    -114.58     33.61
# 7    -114.59     34.83
# 8    -114.59     33.61
# 9    -114.60     34.83

# %% [markdown]
# ### 列名で列を指定する

# %%
df["population"]
# Out:
# 0        1015.0
# 1        1129.0
# 2         333.0
# 3         515.0
# 4         624.0
#           ...
# 16995     907.0
# 16996    1194.0
# 16997    1244.0
# 16998    1298.0
# 16999     806.0
# Name: population, Length: 17000, dtype: float64

# %%
type(df["population"])
# Out:
# pandas.core.series.Series

# %%
df.population
# Out:
# 0        1015.0
# 1        1129.0
# 2         333.0
# 3         515.0
# 4         624.0
#           ...
# 16995     907.0
# 16996    1194.0
# 16997    1244.0
# 16998    1298.0
# 16999     806.0
# Name: population, Length: 17000, dtype: float64

# %%
df[["total_rooms", "households", "median_income"]]
# Out:
#        total_rooms  households  median_income
# 0           5612.0       472.0         1.4936
# 1           7650.0       463.0         1.8200
# 2            720.0       117.0         1.6509
# 3           1501.0       226.0         3.1917
# 4           1454.0       262.0         1.9250
# ...            ...         ...            ...
# 16995       2217.0       369.0         2.3571
# 16996       2349.0       465.0         2.5179
# 16997       2677.0       456.0         3.0313
# 16998       2672.0       478.0         1.9797
# 16999       1820.0       270.0         3.0147
#
# [17000 rows x 3 columns]

# %%
# 列を「households」「median_income」に絞ったあと、10行目から19行目までを指定
df[["households", "median_income"]].iloc[10:20, :]
# Out:
#     households  median_income
# 10       824.0         2.6797
# 11       437.0         1.6250
# 12       211.0         2.1571
# 13       479.0         3.2120
# 14       300.0         0.8585
# 15       401.0         1.6991
# 16       256.0         2.9653
# 17        27.0         0.8571
# 18       320.0         1.2049
# 19        15.0         1.2656

# %%
# 逆に、行を指定したあと、それによって得られるDataFrameの「median_income」列を指定する
df.iloc[100:109, :]["median_income"]
# Out:
# 100    6.3814
# 101    2.5769
# 102    2.4511
# 103    4.1293
# 104    2.2969
# 105    2.0463
# 106    3.1667
# 107    2.1792
# 108    2.0938
# Name: median_income, dtype: float64

# %% [markdown]
# ### 特定の条件による抽出

# %% [markdown]
# #### `.query()`メソッドを使う方法

# %%
# 世帯数が30未満の地域
df.query("households < 30")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17       -114.65     32.79                21.0         44.0            33.0
# 19       -114.67     33.92                17.0         97.0            24.0
# 113      -115.80     33.26                 2.0         96.0            18.0
# 116      -115.88     32.93                15.0        208.0            49.0
# 120      -115.94     33.38                 5.0        186.0            43.0
# ...          ...       ...                 ...          ...             ...
# 16561    -122.69     39.04                 9.0        254.0            50.0
# 16597    -122.71     38.91                20.0         41.0            18.0
# 16733    -122.89     39.42                16.0        411.0           114.0
# 16743    -122.91     39.18                43.0         89.0            18.0
# 16801    -123.17     40.31                36.0         98.0            28.0
#
# ...

# %% [markdown]
# #### 真偽値で指定する方法

# %%
# 人口が1000人以下か
df["population"] <= 1000
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 16995     True
# 16996    False
# 16997    False
# 16998    False
# 16999     True
# Name: population, Length: 17000, dtype: bool

# %%
# 人口が1000人以下の地域
df[df["population"] <= 1000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# 5        -114.58     33.63                29.0       1387.0           236.0
# 7        -114.59     34.83                41.0        812.0           168.0
# ...          ...       ...                 ...          ...             ...
# 16989    -124.21     40.75                32.0       1218.0           331.0
# 16992    -124.23     40.81                52.0       1112.0           209.0
# 16994    -124.25     40.28                32.0       1430.0           419.0
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# #### 複数の条件を指定する

# %% [markdown]
# ##### `query()` の場合

# %%
df.query("population > 100 and households < 30")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2065     -117.33     33.97                 8.0        152.0            19.0
# 2164     -117.37     33.98                52.0        201.0            44.0
# 2379     -117.53     34.02                19.0        256.0            34.0
# 3630     -117.92     34.07                38.0        175.0            22.0
# 4001     -117.97     34.11                18.0        123.0            28.0
# 4461     -118.04     34.13                35.0        249.0            31.0
# 8292     -118.45     34.06                52.0        204.0            34.0
# 8472     -118.48     34.02                11.0         72.0            16.0
# 9260     -119.09     34.22                 8.0         40.0            10.0
# 10797    -120.70     35.32                46.0        118.0            17.0
# 12305    -121.50     38.59                43.0         88.0            21.0
# ...

# %%
df.query("population < 100 or households < 30")
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17       -114.65     32.79                21.0         44.0            33.0
# 19       -114.67     33.92                17.0         97.0            24.0
# 113      -115.80     33.26                 2.0         96.0            18.0
# 116      -115.88     32.93                15.0        208.0            49.0
# 120      -115.94     33.38                 5.0        186.0            43.0
# ...          ...       ...                 ...          ...             ...
# 16643    -122.74     39.71                16.0        255.0            73.0
# 16733    -122.89     39.42                16.0        411.0           114.0
# 16743    -122.91     39.18                43.0         89.0            18.0
# 16801    -123.17     40.31                36.0         98.0            28.0
# 16851    -123.43     40.22                20.0        133.0            35.0
#
# ...

# %% [markdown]
# ##### `query()` を使わない方法による複数条件の指定

# %%
df[(df["population"] > 100) & (df["households"]  < 30)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2065     -117.33     33.97                 8.0        152.0            19.0
# 2164     -117.37     33.98                52.0        201.0            44.0
# 2379     -117.53     34.02                19.0        256.0            34.0
# 3630     -117.92     34.07                38.0        175.0            22.0
# 4001     -117.97     34.11                18.0        123.0            28.0
# 4461     -118.04     34.13                35.0        249.0            31.0
# 8292     -118.45     34.06                52.0        204.0            34.0
# 8472     -118.48     34.02                11.0         72.0            16.0
# 9260     -119.09     34.22                 8.0         40.0            10.0
# 10797    -120.70     35.32                46.0        118.0            17.0
# 12305    -121.50     38.59                43.0         88.0            21.0
# ...

# %%
df[(df["population"] < 100) | (df["households"]  < 30)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 17       -114.65     32.79                21.0         44.0            33.0
# 19       -114.67     33.92                17.0         97.0            24.0
# 113      -115.80     33.26                 2.0         96.0            18.0
# 116      -115.88     32.93                15.0        208.0            49.0
# 120      -115.94     33.38                 5.0        186.0            43.0
# ...          ...       ...                 ...          ...             ...
# 16643    -122.74     39.71                16.0        255.0            73.0
# 16733    -122.89     39.42                16.0        411.0           114.0
# 16743    -122.91     39.18                43.0         89.0            18.0
# 16801    -123.17     40.31                36.0         98.0            28.0
# 16851    -123.43     40.22                20.0        133.0            35.0
#
# ...

# %% [markdown]
# ## 分析を行う

# %% [markdown]
# ### データを分析する

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925208           -0.114250     0.047010
# latitude            -0.925208  1.000000            0.016454    -0.038773
# housing_median_age  -0.114250  0.016454            1.000000    -0.360984
# total_rooms          0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms       0.071802 -0.069373           -0.320434     0.928403
# population           0.101674 -0.111261           -0.295890     0.860170
# households           0.059628 -0.074902           -0.302754     0.919018
# median_income       -0.015485 -0.080303           -0.115932     0.195383
# median_house_value  -0.044982 -0.144917            0.106758     0.130991
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071802    0.101674    0.059628      -0.015485
# latitude                 -0.069373   -0.111261   -0.074902      -0.080303
# ...

# %% [markdown]
# ### データを可視化する

# %%
pd.plotting.scatter_matrix(df[['population', 'median_income', 'households']])
# Out:
# array([[<Axes: xlabel='population', ylabel='population'>,
#         <Axes: xlabel='median_income', ylabel='population'>,
#         <Axes: xlabel='households', ylabel='population'>],
#        [<Axes: xlabel='population', ylabel='median_income'>,
#         <Axes: xlabel='median_income', ylabel='median_income'>,
#         <Axes: xlabel='households', ylabel='median_income'>],
#        [<Axes: xlabel='population', ylabel='households'>,
#         <Axes: xlabel='median_income', ylabel='households'>,
#         <Axes: xlabel='households', ylabel='households'>]], dtype=object)

# %% [markdown]
# ## 列を更新・追加する

# %% [markdown]
# ### データ型の変更

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df[['households', 'population']] = df[['households', 'population']].astype(int)
df[['households', 'population']]
# Out:
#        households  population
# 0             472        1015
# 1             463        1129
# 2             117         333
# 3             226         515
# 4             262         624
# ...           ...         ...
# 16995         369         907
# 16996         465        1194
# 16997         456        1244
# 16998         478        1298
# 16999         270         806
#
# [17000 rows x 2 columns]

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df["median_income"] = df.median_income.apply(round)
df[["median_income"]]
# Out:
#        median_income
# 0                  1
# 1                  2
# 2                  2
# 3                  3
# 4                  2
# ...              ...
# 16995              2
# 16996              3
# 16997              3
# 16998              2
# 16999              3
#
# [17000 rows x 1 columns]

# %% [markdown]
# ### 列の追加

# %%
df["households_per_capita"] = df.households / df.population
df[["households_per_capita"]]
# Out:
#        households_per_capita
# 0                   0.465025
# 1                   0.410097
# 2                   0.351351
# 3                   0.438835
# 4                   0.419872
# ...                      ...
# 16995               0.406836
# 16996               0.389447
# 16997               0.366559
# 16998               0.368259
# 16999               0.334988
#
# [17000 rows x 1 columns]

# %% [markdown]
# ## NumPyとの関係

# %% [markdown]
# ### DataFrameからndarrayを取り出す

# %%
df.values
# Out:
# array([[-1.14310000e+02,  3.41900000e+01,  1.50000000e+01, ...,
#          1.00000000e+00,  6.69000000e+04,  4.65024631e-01],
#        [-1.14470000e+02,  3.44000000e+01,  1.90000000e+01, ...,
#          2.00000000e+00,  8.01000000e+04,  4.10097431e-01],
#        [-1.14560000e+02,  3.36900000e+01,  1.70000000e+01, ...,
#          2.00000000e+00,  8.57000000e+04,  3.51351351e-01],
#        ...,
#        [-1.24300000e+02,  4.18400000e+01,  1.70000000e+01, ...,
#          3.00000000e+00,  1.03600000e+05,  3.66559486e-01],
#        [-1.24300000e+02,  4.18000000e+01,  1.90000000e+01, ...,
#          2.00000000e+00,  8.58000000e+04,  3.68258860e-01],
#        [-1.24350000e+02,  4.05400000e+01,  5.20000000e+01, ...,
#          3.00000000e+00,  9.46000000e+04,  3.34987593e-01]])

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'households_per_capita'],
#       dtype='object')

# %%
for column in df.columns:
    print(column)
# Out:
# longitude
# latitude
# housing_median_age
# total_rooms
# total_bedrooms
# population
# households
# median_income
# median_house_value
# households_per_capita

# %%
data_by_columns = {}
for i, column in enumerate(df.columns):
    data_by_columns[column] = df.values[:, i]

data_by_columns
# Out:
# {'longitude': array([-114.31, -114.47, -114.56, ..., -124.3 , -124.3 , -124.35]),
#  'latitude': array([34.19, 34.4 , 33.69, ..., 41.84, 41.8 , 40.54]),
#  'housing_median_age': array([15., 19., 17., ..., 17., 19., 52.]),
#  'total_rooms': array([5612., 7650.,  720., ..., 2677., 2672., 1820.]),
#  'total_bedrooms': array([1283., 1901.,  174., ...,  531.,  552.,  300.]),
#  'population': array([1015., 1129.,  333., ..., 1244., 1298.,  806.]),
#  'households': array([472., 463., 117., ..., 456., 478., 270.]),
#  'median_income': array([1., 2., 2., ..., 3., 2., 3.]),
#  'median_house_value': array([ 66900.,  80100.,  85700., ..., 103600.,  85800.,  94600.]),
#  'households_per_capita': array([0.46502463, 0.41009743, 0.35135135, ..., 0.36655949, 0.36825886,
#         0.33498759])}

# %% [markdown]
# ### ndarrayからDataFrameを取得する

# %%
df_recover = pd.DataFrame(data_by_columns)
df_recover
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %% [markdown]
# ## CSVファイルに書き込む

# %%
df.to_csv("sample.csv")

# %%
df.to_csv("sample.csv", index=False)
